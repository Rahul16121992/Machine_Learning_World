# %% [markdown]
# # What is Machine Learning

# %% [markdown]
# Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.

# %% [markdown]
# ![60f6feb4be651f666b46194a_AI%20vs%20Machine%20Learning%20vs%20Deep%20Learning.jpg](attachment:60f6feb4be651f666b46194a_AI%20vs%20Machine%20Learning%20vs%20Deep%20Learning.jpg)

# %% [markdown]
# ![AI-Definition.webp](attachment:AI-Definition.webp)

# %% [markdown]
# ![introduction-to-machine-learning.png](attachment:introduction-to-machine-learning.png)

# %% [markdown]
# ![what-is-machine-learning-7-steps-of-machine-learning.jpg](attachment:what-is-machine-learning-7-steps-of-machine-learning.jpg)

# %% [markdown]
# ![4-12-1.png](attachment:4-12-1.png)
